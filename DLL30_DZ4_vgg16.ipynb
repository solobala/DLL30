# %% [markdown]
# <a href="https://www.kaggle.com/code/marinabalakina/dll30-dz4-2?scriptVersionId=155042589" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# ** Домашнее** задание по теме «Архитектуры свёрточных сетей»

Цель задания: изучить работу с готовыми моделями из torchvision.

Контекст

Вам необходимо подобрать базовую модель для работы по вашей задаче. Вы пробуете обучать различные модели на “ваших” данных. По результатам отберёте лучшую для дальнейшего обучения.

Задание

Вам необходимо провести эксперименты по начальному обучению различных моделей и сравнить результаты.

1.Возьмите датасет EMNIST из torchvision

2. Обучите на нём модели: ResNet 18, VGG 16, Inception v3, DenseNet 161 (с нуля по 10 эпох)

3. Сведите результаты обучения моделей (графики лоса) в таблицу и сравните их.


Задание со звездочкой*

* Выполните то же задание, используя датасет hymenoptera_data

Инструкция к выполнению задания

* Загрузите датасет, посмотрите примеры картинок в нём и проверьте наличествующие классы и их дисбаланс.

* Создайте модель текущего типа, используя интерфейс torchvision для нужного количества классов.

* Обучите модель с нуля 10 эпох. Фиксируйте значение функции потерь в список для последующего отображения.

Повторите пункты 2 и 3 для всех указанных вариантов моделей.

Формат сдачи работы

Прикрепите ссылку на готовое решение в личном кабинете. Работу можно отправлять в виде ссылки на python-ноутбук из GitHub, Google Colaboratory или аналогичных платформ. Не забудьте открыть доступ на просмотр и комментирование.

Критерии оценивания
По итогу выполнения задания вы получите зачёт.

Задание считается выполненным, если:

вы обучили каждую модель до некоторого улучшения качества

составлена таблица обучения для сравнения

Задание будет отправлено на доработку, если:

использованы не все типы моделей

не составлена сводная таблица с результатами

# %% [markdown]
# # Импорт библиотек и пользовательские функции

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
import torch
from torch import nn
import torchvision as tv # consists of popular datasets, model architectures, and common image transformations for computer vision - для работы с предобученными нейросетями
import time

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
def evaluate_accuracy(data_iter, net):
    acc_sum, n = 0, 0
    net.eval()
    for X, y in data_iter:
        X, y = X.to(device), y.to(device)
        acc_sum += (net(X).argmax(axis=1) == y).sum()
        n += y.shape[0]
    return acc_sum.item() / n

# %%
def train(net, train_iter, test_iter, trainer, num_epochs):
    net.to(device)
    loss = nn.CrossEntropyLoss(reduction='sum')
    net.train()
    train_accuracy, train_losses, test_accuracy =[], [], []
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()

        for i, (X, y) in enumerate(train_iter):
            X, y = X.to(device), y.to(device)
            trainer.zero_grad()
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.shape[0]

            if i % 10 == 0:
              print(f"Step {i}. time since epoch: {time.time() -  start:.3f}. "
                    f"Train acc: {train_acc_sum / n:.3f}. Train Loss: {train_l_sum / n:.3f}")
        test_acc = evaluate_accuracy(test_iter, net.to(device))
        print('-' * 20)
        print(f'epoch {epoch + 1}, loss {train_l_sum / n:.4f}, train acc {train_acc_sum / n:.3f}'
              f', test acc {test_acc:.3f}, time {time.time() - start:.1f} sec')
        train_accuracy.append(train_acc_sum / n)
        train_losses.append(train_l_sum / n)
        test_accuracy.append(test_acc)
    return train_accuracy, train_losses, test_accuracy

# %%
BATCH_SIZE = 256
# Переводим картинки в 224х224 и в тензор
transoforms = tv.transforms.Compose([

    tv.transforms.Resize((224, 224)),
    tv.transforms.ToTensor()
])
train_dataset = tv.datasets.EMNIST('.', split='mnist', train=True, transform=transoforms, download=True)
test_dataset = tv.datasets.EMNIST('.', split='mnist', train=False, transform=transoforms, download=True)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %% [markdown]
# ## 1.1. Визуализация

# %%
train_dataset.classes

# %%
labels_map={
    0: '48',
    1: '49',
    2: '50',
    3: '51',
    4: '52',
    5: '53',
    6: '54',
    7: '55',
    8: '56',
    9: '57',
}

figure = plt.figure(figsize = (10,10))
cols, rows = 3, 3

for i in range (1, cols*rows + 1):
    sample_idx = torch.randint(len(train_dataset), size = (1,)).item()
    image, label = train_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis('off')
    plt.imshow(image.squeeze(), cmap='gray')
plt.show()

# %%
# считаем количество элементов
targets = train_dataset.targets
counts = torch.bincount(targets)
for i, count in enumerate(counts):
    print(f"{i}: {count}")

# %% [markdown]
# Классы сбалансированы

# %% [markdown]
# # 2. Обучение моделей

# %% [markdown]
# ## 2.1. ResNET 18

# %%
classification_models = tv.models.list_models(module=tv.models)

# %%
classification_models

# %%
# Если брать предобученные модели из torchvision.models, то они обучены на изображениях (224,224,3). Поэтому на до перетрансформировать датасеты 
transoforms = tv.transforms.Compose([
    tv.transforms.Grayscale(3),
    tv.transforms.Resize((224, 224)),
    tv.transforms.ToTensor()
])

train_dataset = tv.datasets.MNIST('.', train=True, transform=transoforms, download=True)
test_dataset = tv.datasets.MNIST('.', train=False, transform=transoforms, download=True)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
model = tv.models.resnet18(pretrained=True)

# %%
model

# %%
# Убираем требование градиента:
for param in model.parameters():
    param.requires_grad = False

# %%
model.fc

# %%
model.fc = nn.Linear(in_features=512, out_features=10)

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

# %%
trainer = torch.optim.Adam(params_to_update, lr=0.001)

# %%
train_accuracy, train_losses, test_accuracy = train(model, train_iter, test_iter, trainer, 10)

# %%
df_results= pd.DataFrame(columns = ['model', 'train_accuracy', 'train_loss', 'test_accuracy','epoch'])
for i in range(10):
  df_results.loc[len(df_results.index)] = ['resnet18',  train_accuracy[i], train_losses[i], test_accuracy[i], i]

# %%
df_results

# %%
df_results.to_csv('resnet.csv', index=False)

# %% [markdown]
# ## 2.2. VGG16

# %%
torch.cuda.empty_cache()

# %%
BATCH_SIZE = 256
# Переводим картинки в 224х224 и в тензор
transoforms = tv.transforms.Compose([

    tv.transforms.Resize((224, 224)),
    tv.transforms.ToTensor()
])
train_dataset = tv.datasets.EMNIST('.', split='mnist', train=True, transform=transoforms, download=True)
test_dataset = tv.datasets.EMNIST('.', split='mnist', train=False, transform=transoforms, download=True)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
def vgg_block(num_convs, input_channels, num_channels):
    blk = nn.Sequential(nn.Conv2d(input_channels, num_channels, kernel_size=3, padding=1), nn.ReLU())
    for i in range(num_convs - 1):
        blk.add_module("conv{}".format(i), nn.Conv2d(num_channels, num_channels, kernel_size=3, padding=1))
        blk.add_module("relu{}".format(i), nn.ReLU())
    blk.add_module("pool", nn.MaxPool2d(2, stride=2))
    return blk

# %%
def vgg(conv_arch):
    net = nn.Sequential()

    for i, (num_convs, input_ch, num_channels) in enumerate(conv_arch):
        net.add_module("block{}".format(i), vgg_block(num_convs, input_ch, num_channels))


    classifier = nn.Sequential(
        nn.Flatten(),

        # nn.Linear(25088, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(6272, 4096), nn.ReLU(), nn.Dropout(0.5),

        nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 10))

    net.add_module('classifier', classifier)
    return net

# %%
conv_arch = ((1, 1, 64), (1, 64, 128), (2, 128, 256), (2, 256, 512), (2, 512, 512))

# %%
ratio = 4
small_conv_arch = [(v[0], max(v[1] // ratio, 1), v[2] // ratio) for v in conv_arch]
net = vgg(small_conv_arch)

# %%
lr, num_epochs = 0.001, 10
trainer = torch.optim.Adam(net.parameters(), lr=lr)

# %%
train_accuracy, train_losses, test_accuracy  = train(net, train_iter, test_iter, trainer, num_epochs)
# Out:
# Step 0. time since epoch: 1.671. Train acc: 0.098. Train Loss: 2.302
# Step 10. time since epoch: 5.247. Train acc: 0.096. Train Loss: 2.307
# Step 20. time since epoch: 8.833. Train acc: 0.100. Train Loss: 2.305
# Step 30. time since epoch: 12.392. Train acc: 0.116. Train Loss: 2.284
# Step 40. time since epoch: 15.940. Train acc: 0.222. Train Loss: 2.066
# Step 50. time since epoch: 19.526. Train acc: 0.332. Train Loss: 1.788
# Step 60. time since epoch: 23.118. Train acc: 0.422. Train Loss: 1.556
# Step 70. time since epoch: 26.701. Train acc: 0.492. Train Loss: 1.374
# Step 80. time since epoch: 30.248. Train acc: 0.547. Train Loss: 1.232
# Step 90. time since epoch: 33.834. Train acc: 0.591. Train Loss: 1.113
# Step 100. time since epoch: 37.465. Train acc: 0.627. Train Loss: 1.019
# Step 110. time since epoch: 41.080. Train acc: 0.657. Train Loss: 0.939
# Step 120. time since epoch: 44.652. Train acc: 0.683. Train Loss: 0.870
# Step 130. time since epoch: 48.245. Train acc: 0.705. Train Loss: 0.812
# Step 140. time since epoch: 51.841. Train acc: 0.724. Train Loss: 0.761
# Step 150. time since epoch: 55.427. Train acc: 0.740. Train Loss: 0.718
# Step 160. time since epoch: 59.007. Train acc: 0.754. Train Loss: 0.679
# Step 170. time since epoch: 62.581. Train acc: 0.767. Train Loss: 0.645
# Step 180. time since epoch: 66.135. Train acc: 0.778. Train Loss: 0.615
# Step 190. time since epoch: 69.718. Train acc: 0.788. Train Loss: 0.587
# Step 200. time since epoch: 73.266. Train acc: 0.798. Train Loss: 0.562
# Step 210. time since epoch: 76.800. Train acc: 0.806. Train Loss: 0.539
# Step 220. time since epoch: 80.347. Train acc: 0.814. Train Loss: 0.518
# Step 230. time since epoch: 83.906. Train acc: 0.821. Train Loss: 0.498
# --------------------
# epoch 1, loss 0.4919, train acc 0.823, test acc 0.982, time 91.9 sec
# Step 0. time since epoch: 0.364. Train acc: 0.973. Train Loss: 0.061
# Step 10. time since epoch: 3.915. Train acc: 0.979. Train Loss: 0.061
# Step 20. time since epoch: 7.500. Train acc: 0.980. Train Loss: 0.063
# Step 30. time since epoch: 11.098. Train acc: 0.981. Train Loss: 0.060
# Step 40. time since epoch: 14.639. Train acc: 0.981. Train Loss: 0.061
# Step 50. time since epoch: 18.214. Train acc: 0.982. Train Loss: 0.059
# Step 60. time since epoch: 21.827. Train acc: 0.982. Train Loss: 0.059
# Step 70. time since epoch: 25.395. Train acc: 0.983. Train Loss: 0.058
# Step 80. time since epoch: 29.001. Train acc: 0.982. Train Loss: 0.059
# Step 90. time since epoch: 32.579. Train acc: 0.983. Train Loss: 0.058
# Step 100. time since epoch: 36.155. Train acc: 0.983. Train Loss: 0.057
# Step 110. time since epoch: 39.731. Train acc: 0.983. Train Loss: 0.057
# Step 120. time since epoch: 43.306. Train acc: 0.983. Train Loss: 0.057
# Step 130. time since epoch: 46.876. Train acc: 0.983. Train Loss: 0.056
# Step 140. time since epoch: 50.446. Train acc: 0.984. Train Loss: 0.055
# Step 150. time since epoch: 54.016. Train acc: 0.984. Train Loss: 0.055
# Step 160. time since epoch: 57.578. Train acc: 0.984. Train Loss: 0.053
# Step 170. time since epoch: 61.256. Train acc: 0.984. Train Loss: 0.053
# Step 180. time since epoch: 64.844. Train acc: 0.985. Train Loss: 0.052
# Step 190. time since epoch: 68.431. Train acc: 0.985. Train Loss: 0.052
# Step 200. time since epoch: 72.021. Train acc: 0.985. Train Loss: 0.052
# Step 210. time since epoch: 75.606. Train acc: 0.985. Train Loss: 0.051
# Step 220. time since epoch: 79.183. Train acc: 0.985. Train Loss: 0.050
# Step 230. time since epoch: 82.778. Train acc: 0.985. Train Loss: 0.049
# --------------------
# epoch 2, loss 0.0489, train acc 0.986, test acc 0.988, time 90.8 sec
# Step 0. time since epoch: 0.384. Train acc: 0.984. Train Loss: 0.037
# Step 10. time since epoch: 3.954. Train acc: 0.992. Train Loss: 0.032
# Step 20. time since epoch: 7.552. Train acc: 0.991. Train Loss: 0.035
# Step 30. time since epoch: 11.134. Train acc: 0.990. Train Loss: 0.036
# Step 40. time since epoch: 14.691. Train acc: 0.989. Train Loss: 0.036
# Step 50. time since epoch: 18.261. Train acc: 0.990. Train Loss: 0.034
# Step 60. time since epoch: 21.807. Train acc: 0.990. Train Loss: 0.035
# Step 70. time since epoch: 25.349. Train acc: 0.989. Train Loss: 0.035
# Step 80. time since epoch: 28.895. Train acc: 0.989. Train Loss: 0.035
# Step 90. time since epoch: 32.511. Train acc: 0.989. Train Loss: 0.035
# Step 100. time since epoch: 36.038. Train acc: 0.989. Train Loss: 0.035
# Step 110. time since epoch: 39.600. Train acc: 0.989. Train Loss: 0.036
# Step 120. time since epoch: 43.137. Train acc: 0.989. Train Loss: 0.036
# Step 130. time since epoch: 46.689. Train acc: 0.989. Train Loss: 0.035
# Step 140. time since epoch: 50.240. Train acc: 0.990. Train Loss: 0.034
# Step 150. time since epoch: 53.772. Train acc: 0.990. Train Loss: 0.034
# Step 160. time since epoch: 57.289. Train acc: 0.990. Train Loss: 0.033
# Step 170. time since epoch: 60.854. Train acc: 0.990. Train Loss: 0.033
# Step 180. time since epoch: 64.476. Train acc: 0.990. Train Loss: 0.033
# Step 190. time since epoch: 68.030. Train acc: 0.990. Train Loss: 0.034
# Step 200. time since epoch: 71.608. Train acc: 0.990. Train Loss: 0.033
# Step 210. time since epoch: 75.147. Train acc: 0.990. Train Loss: 0.033
# Step 220. time since epoch: 78.708. Train acc: 0.990. Train Loss: 0.032
# Step 230. time since epoch: 82.246. Train acc: 0.990. Train Loss: 0.032
# --------------------
# epoch 3, loss 0.0317, train acc 0.990, test acc 0.990, time 90.0 sec
# Step 0. time since epoch: 0.378. Train acc: 0.996. Train Loss: 0.023
# Step 10. time since epoch: 3.938. Train acc: 0.991. Train Loss: 0.025
# Step 20. time since epoch: 7.524. Train acc: 0.992. Train Loss: 0.025
# Step 30. time since epoch: 11.087. Train acc: 0.991. Train Loss: 0.026
# Step 40. time since epoch: 14.618. Train acc: 0.992. Train Loss: 0.027
# Step 50. time since epoch: 18.159. Train acc: 0.992. Train Loss: 0.025
# Step 60. time since epoch: 21.700. Train acc: 0.993. Train Loss: 0.024
# Step 70. time since epoch: 25.239. Train acc: 0.993. Train Loss: 0.024
# Step 80. time since epoch: 28.790. Train acc: 0.992. Train Loss: 0.026
# Step 90. time since epoch: 32.344. Train acc: 0.992. Train Loss: 0.026
# Step 100. time since epoch: 35.921. Train acc: 0.992. Train Loss: 0.026
# Step 110. time since epoch: 39.491. Train acc: 0.992. Train Loss: 0.027
# Step 120. time since epoch: 43.034. Train acc: 0.992. Train Loss: 0.027
# Step 130. time since epoch: 46.587. Train acc: 0.992. Train Loss: 0.027
# Step 140. time since epoch: 50.148. Train acc: 0.992. Train Loss: 0.026
# Step 150. time since epoch: 53.694. Train acc: 0.992. Train Loss: 0.026
# Step 160. time since epoch: 57.254. Train acc: 0.992. Train Loss: 0.026
# Step 170. time since epoch: 60.819. Train acc: 0.992. Train Loss: 0.025
# Step 180. time since epoch: 64.381. Train acc: 0.992. Train Loss: 0.026
# Step 190. time since epoch: 67.974. Train acc: 0.992. Train Loss: 0.026
# Step 200. time since epoch: 71.580. Train acc: 0.992. Train Loss: 0.026
# Step 210. time since epoch: 75.127. Train acc: 0.992. Train Loss: 0.026
# Step 220. time since epoch: 78.675. Train acc: 0.992. Train Loss: 0.026
# Step 230. time since epoch: 82.239. Train acc: 0.993. Train Loss: 0.025
# --------------------
# epoch 4, loss 0.0250, train acc 0.993, test acc 0.992, time 90.1 sec
# Step 0. time since epoch: 0.379. Train acc: 0.992. Train Loss: 0.024
# Step 10. time since epoch: 3.924. Train acc: 0.992. Train Loss: 0.023
# Step 20. time since epoch: 7.525. Train acc: 0.993. Train Loss: 0.022
# Step 30. time since epoch: 11.113. Train acc: 0.993. Train Loss: 0.021
# Step 40. time since epoch: 14.672. Train acc: 0.993. Train Loss: 0.021
# Step 50. time since epoch: 18.223. Train acc: 0.993. Train Loss: 0.020
# Step 60. time since epoch: 21.796. Train acc: 0.994. Train Loss: 0.020
# Step 70. time since epoch: 25.324. Train acc: 0.994. Train Loss: 0.019
# Step 80. time since epoch: 28.912. Train acc: 0.994. Train Loss: 0.020
# Step 90. time since epoch: 32.452. Train acc: 0.994. Train Loss: 0.020
# Step 100. time since epoch: 35.990. Train acc: 0.994. Train Loss: 0.020
# Step 110. time since epoch: 39.696. Train acc: 0.994. Train Loss: 0.020
# Step 120. time since epoch: 43.216. Train acc: 0.994. Train Loss: 0.020
# Step 130. time since epoch: 46.756. Train acc: 0.994. Train Loss: 0.021
# Step 140. time since epoch: 50.312. Train acc: 0.994. Train Loss: 0.020
# Step 150. time since epoch: 53.853. Train acc: 0.994. Train Loss: 0.020
# Step 160. time since epoch: 57.384. Train acc: 0.994. Train Loss: 0.020
# Step 170. time since epoch: 60.927. Train acc: 0.994. Train Loss: 0.020
# Step 180. time since epoch: 64.463. Train acc: 0.994. Train Loss: 0.020
# Step 190. time since epoch: 67.980. Train acc: 0.994. Train Loss: 0.020
# Step 200. time since epoch: 71.634. Train acc: 0.994. Train Loss: 0.020
# Step 210. time since epoch: 75.178. Train acc: 0.994. Train Loss: 0.020
# Step 220. time since epoch: 78.751. Train acc: 0.994. Train Loss: 0.019
# Step 230. time since epoch: 82.278. Train acc: 0.994. Train Loss: 0.019
# --------------------
# epoch 5, loss 0.0191, train acc 0.994, test acc 0.992, time 90.1 sec
# Step 0. time since epoch: 0.358. Train acc: 0.996. Train Loss: 0.008
# Step 10. time since epoch: 3.884. Train acc: 0.995. Train Loss: 0.018
# Step 20. time since epoch: 7.411. Train acc: 0.996. Train Loss: 0.015
# Step 30. time since epoch: 11.012. Train acc: 0.995. Train Loss: 0.015
# Step 40. time since epoch: 14.576. Train acc: 0.995. Train Loss: 0.016
# Step 50. time since epoch: 18.102. Train acc: 0.995. Train Loss: 0.014
# Step 60. time since epoch: 21.651. Train acc: 0.995. Train Loss: 0.015
# Step 70. time since epoch: 25.187. Train acc: 0.995. Train Loss: 0.016
# Step 80. time since epoch: 28.758. Train acc: 0.995. Train Loss: 0.016
# Step 90. time since epoch: 32.328. Train acc: 0.995. Train Loss: 0.017
# Step 100. time since epoch: 35.889. Train acc: 0.995. Train Loss: 0.017
# Step 110. time since epoch: 39.455. Train acc: 0.995. Train Loss: 0.018
# Step 120. time since epoch: 43.076. Train acc: 0.995. Train Loss: 0.018
# Step 130. time since epoch: 46.639. Train acc: 0.995. Train Loss: 0.017
# Step 140. time since epoch: 50.212. Train acc: 0.995. Train Loss: 0.017
# Step 150. time since epoch: 53.765. Train acc: 0.995. Train Loss: 0.017
# Step 160. time since epoch: 57.315. Train acc: 0.995. Train Loss: 0.016
# Step 170. time since epoch: 60.870. Train acc: 0.995. Train Loss: 0.016
# Step 180. time since epoch: 64.412. Train acc: 0.995. Train Loss: 0.017
# Step 190. time since epoch: 68.015. Train acc: 0.995. Train Loss: 0.017
# Step 200. time since epoch: 71.619. Train acc: 0.995. Train Loss: 0.017
# Step 210. time since epoch: 75.199. Train acc: 0.995. Train Loss: 0.016
# Step 220. time since epoch: 78.761. Train acc: 0.995. Train Loss: 0.016
# Step 230. time since epoch: 82.313. Train acc: 0.995. Train Loss: 0.016
# --------------------
# epoch 6, loss 0.0157, train acc 0.995, test acc 0.991, time 90.1 sec
# Step 0. time since epoch: 0.388. Train acc: 0.992. Train Loss: 0.031
# Step 10. time since epoch: 3.923. Train acc: 0.996. Train Loss: 0.017
# Step 20. time since epoch: 7.443. Train acc: 0.997. Train Loss: 0.012
# Step 30. time since epoch: 11.001. Train acc: 0.997. Train Loss: 0.013
# Step 40. time since epoch: 14.551. Train acc: 0.996. Train Loss: 0.014
# Step 50. time since epoch: 18.094. Train acc: 0.996. Train Loss: 0.013
# Step 60. time since epoch: 21.649. Train acc: 0.996. Train Loss: 0.014
# Step 70. time since epoch: 25.209. Train acc: 0.996. Train Loss: 0.013
# Step 80. time since epoch: 28.749. Train acc: 0.996. Train Loss: 0.013
# Step 90. time since epoch: 32.300. Train acc: 0.996. Train Loss: 0.013
# Step 100. time since epoch: 35.836. Train acc: 0.996. Train Loss: 0.014
# Step 110. time since epoch: 39.395. Train acc: 0.996. Train Loss: 0.014
# Step 120. time since epoch: 42.983. Train acc: 0.996. Train Loss: 0.014
# Step 130. time since epoch: 46.573. Train acc: 0.996. Train Loss: 0.014
# Step 140. time since epoch: 50.118. Train acc: 0.996. Train Loss: 0.013
# Step 150. time since epoch: 53.645. Train acc: 0.996. Train Loss: 0.013
# Step 160. time since epoch: 57.175. Train acc: 0.996. Train Loss: 0.013
# Step 170. time since epoch: 60.767. Train acc: 0.996. Train Loss: 0.013
# Step 180. time since epoch: 64.294. Train acc: 0.996. Train Loss: 0.013
# Step 190. time since epoch: 67.828. Train acc: 0.996. Train Loss: 0.013
# Step 200. time since epoch: 71.380. Train acc: 0.996. Train Loss: 0.013
# Step 210. time since epoch: 74.946. Train acc: 0.996. Train Loss: 0.013
# Step 220. time since epoch: 78.590. Train acc: 0.996. Train Loss: 0.013
# Step 230. time since epoch: 82.122. Train acc: 0.996. Train Loss: 0.013
# --------------------
# epoch 7, loss 0.0128, train acc 0.996, test acc 0.991, time 90.0 sec
# Step 0. time since epoch: 0.360. Train acc: 0.996. Train Loss: 0.016
# Step 10. time since epoch: 3.905. Train acc: 0.993. Train Loss: 0.021
# Step 20. time since epoch: 7.438. Train acc: 0.995. Train Loss: 0.016
# Step 30. time since epoch: 10.985. Train acc: 0.995. Train Loss: 0.016
# Step 40. time since epoch: 14.543. Train acc: 0.995. Train Loss: 0.016
# Step 50. time since epoch: 18.095. Train acc: 0.996. Train Loss: 0.014
# Step 60. time since epoch: 21.671. Train acc: 0.996. Train Loss: 0.014
# Step 70. time since epoch: 25.220. Train acc: 0.996. Train Loss: 0.014
# Step 80. time since epoch: 28.763. Train acc: 0.996. Train Loss: 0.014
# Step 90. time since epoch: 32.347. Train acc: 0.996. Train Loss: 0.014
# Step 100. time since epoch: 35.881. Train acc: 0.996. Train Loss: 0.013
# Step 110. time since epoch: 39.435. Train acc: 0.996. Train Loss: 0.014
# Step 120. time since epoch: 42.968. Train acc: 0.996. Train Loss: 0.014
# Step 130. time since epoch: 46.562. Train acc: 0.996. Train Loss: 0.014
# Step 140. time since epoch: 50.181. Train acc: 0.996. Train Loss: 0.013
# Step 150. time since epoch: 53.725. Train acc: 0.996. Train Loss: 0.013
# Step 160. time since epoch: 57.260. Train acc: 0.996. Train Loss: 0.013
# Step 170. time since epoch: 60.826. Train acc: 0.996. Train Loss: 0.013
# Step 180. time since epoch: 64.359. Train acc: 0.996. Train Loss: 0.013
# Step 190. time since epoch: 67.946. Train acc: 0.996. Train Loss: 0.013
# Step 200. time since epoch: 71.519. Train acc: 0.996. Train Loss: 0.013
# Step 210. time since epoch: 75.085. Train acc: 0.996. Train Loss: 0.013
# Step 220. time since epoch: 78.654. Train acc: 0.996. Train Loss: 0.013
# Step 230. time since epoch: 82.274. Train acc: 0.996. Train Loss: 0.013
# --------------------
# epoch 8, loss 0.0127, train acc 0.996, test acc 0.992, time 90.1 sec
# Step 0. time since epoch: 0.365. Train acc: 0.996. Train Loss: 0.005
# Step 10. time since epoch: 3.912. Train acc: 0.995. Train Loss: 0.013
# Step 20. time since epoch: 7.469. Train acc: 0.995. Train Loss: 0.012
# Step 30. time since epoch: 11.040. Train acc: 0.996. Train Loss: 0.011
# Step 40. time since epoch: 14.596. Train acc: 0.996. Train Loss: 0.011
# Step 50. time since epoch: 18.173. Train acc: 0.996. Train Loss: 0.011
# Step 60. time since epoch: 21.735. Train acc: 0.996. Train Loss: 0.011
# Step 70. time since epoch: 25.337. Train acc: 0.996. Train Loss: 0.012
# Step 80. time since epoch: 28.886. Train acc: 0.996. Train Loss: 0.012
# Step 90. time since epoch: 32.414. Train acc: 0.996. Train Loss: 0.012
# Step 100. time since epoch: 35.994. Train acc: 0.996. Train Loss: 0.012
# Step 110. time since epoch: 39.601. Train acc: 0.996. Train Loss: 0.012
# Step 120. time since epoch: 43.158. Train acc: 0.996. Train Loss: 0.012
# Step 130. time since epoch: 46.732. Train acc: 0.996. Train Loss: 0.012
# Step 140. time since epoch: 50.340. Train acc: 0.996. Train Loss: 0.012
# Step 150. time since epoch: 54.089. Train acc: 0.996. Train Loss: 0.012
# Step 160. time since epoch: 57.739. Train acc: 0.996. Train Loss: 0.012
# Step 170. time since epoch: 61.383. Train acc: 0.996. Train Loss: 0.012
# Step 180. time since epoch: 64.970. Train acc: 0.996. Train Loss: 0.012
# Step 190. time since epoch: 68.549. Train acc: 0.996. Train Loss: 0.011
# Step 200. time since epoch: 72.134. Train acc: 0.996. Train Loss: 0.011
# Step 210. time since epoch: 75.824. Train acc: 0.996. Train Loss: 0.011
# Step 220. time since epoch: 79.486. Train acc: 0.996. Train Loss: 0.011
# Step 230. time since epoch: 83.265. Train acc: 0.996. Train Loss: 0.011
# --------------------
# epoch 9, loss 0.0113, train acc 0.996, test acc 0.987, time 91.5 sec
# Step 0. time since epoch: 0.366. Train acc: 0.988. Train Loss: 0.037
# Step 10. time since epoch: 3.998. Train acc: 0.995. Train Loss: 0.021
# Step 20. time since epoch: 7.633. Train acc: 0.996. Train Loss: 0.015
# Step 30. time since epoch: 11.234. Train acc: 0.996. Train Loss: 0.015
# Step 40. time since epoch: 14.817. Train acc: 0.996. Train Loss: 0.014
# Step 50. time since epoch: 18.422. Train acc: 0.996. Train Loss: 0.012
# Step 60. time since epoch: 22.000. Train acc: 0.997. Train Loss: 0.011
# Step 70. time since epoch: 25.633. Train acc: 0.997. Train Loss: 0.011
# Step 80. time since epoch: 29.241. Train acc: 0.997. Train Loss: 0.011
# Step 90. time since epoch: 32.790. Train acc: 0.997. Train Loss: 0.010
# Step 100. time since epoch: 36.332. Train acc: 0.997. Train Loss: 0.010
# Step 110. time since epoch: 39.909. Train acc: 0.997. Train Loss: 0.010
# Step 120. time since epoch: 43.475. Train acc: 0.997. Train Loss: 0.010
# Step 130. time since epoch: 47.106. Train acc: 0.997. Train Loss: 0.010
# Step 140. time since epoch: 50.662. Train acc: 0.997. Train Loss: 0.010
# Step 150. time since epoch: 54.248. Train acc: 0.997. Train Loss: 0.010
# Step 160. time since epoch: 57.931. Train acc: 0.997. Train Loss: 0.010
# Step 170. time since epoch: 61.507. Train acc: 0.997. Train Loss: 0.010
# Step 180. time since epoch: 65.066. Train acc: 0.997. Train Loss: 0.010
# Step 190. time since epoch: 68.610. Train acc: 0.997. Train Loss: 0.011
# Step 200. time since epoch: 72.158. Train acc: 0.997. Train Loss: 0.011
# Step 210. time since epoch: 75.725. Train acc: 0.997. Train Loss: 0.010
# Step 220. time since epoch: 79.295. Train acc: 0.997. Train Loss: 0.010
# Step 230. time since epoch: 82.867. Train acc: 0.997. Train Loss: 0.010
# --------------------
# epoch 10, loss 0.0100, train acc 0.997, test acc 0.991, time 90.8 sec

# %%
df_results= pd.DataFrame(columns = ['model', 'train_accuracy', 'train_loss', 'test_accuracy','epoch'])
for i in range(10):
  df_results.loc[len(df_results.index)] = ['vgg16',  train_accuracy[i], train_losses[i], test_accuracy[i], i]

# %%
df_results
# Out:
#    model  train_accuracy  train_loss  test_accuracy  epoch
# 0  vgg16        0.823417    0.491901         0.9816      0
# 1  vgg16        0.985533    0.048897         0.9875      1
# 2  vgg16        0.990450    0.031727         0.9901      2
# 3  vgg16        0.992567    0.024981         0.9918      3
# 4  vgg16        0.994383    0.019147         0.9923      4
# 5  vgg16        0.995317    0.015705         0.9911      5
# 6  vgg16        0.996283    0.012776         0.9911      6
# 7  vgg16        0.995800    0.012743         0.9921      7
# 8  vgg16        0.996333    0.011288         0.9871      8
# 9  vgg16        0.997017    0.009972         0.9912      9

# %%
df_results.to_csv('vgg16.csv', index=False)

# %% [markdown]
# ## 2.3. Inception v3

# %%
torch.cuda.empty_cache()
model = tv.models.inception_v3(pretrained=True)

# %%
model

# %%
# Убираем требование градиента:
for param in model.parameters():
    param.requires_grad = False

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

# %%
lr, num_epochs = 0.001, 1
trainer = torch.optim.Adam(params_to_update, lr=lr)
train_accuracy, train_losses, test_accuracy  = train(model, train_iter, test_iter, trainer, num_epochs)

# %%
for i in range(10):
  df_results.loc[len(df_results.index)] = ['inception_v3',  train_accuracy[i], train_losses[i], test_accuracy[i], i]

# %% [markdown]
# ## 2.4. DenseNet 161

# %%
torch.cuda.empty_cache()

# %%
model = tv.models.densenet161(pretrained=True)

# %%
model

# %%
# Убираем требование градиента:
for param in model.parameters():
    param.requires_grad = False

# %%
model.classifier

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

# %%
trainer = torch.optim.Adam(params_to_update, lr=0.001)
train_accuracy, train_losses, test_accuracy  = train(model, train_iter, test_iter, trainer, num_epochs)

# %%
for i in range(10):
  df_results.loc[len(df_results.index)] = ['densenet161',  train_accuracy[i], train_losses[i], test_accuracy[i], i]
